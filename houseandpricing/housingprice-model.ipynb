# %%
import pandas as pd

# %%
dataset = pd.read_csv("ParisHousing.csv")

# %%
dataset.head()
# Out:
#    squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0         75523              3        0        1      63      9373
# 1         80771             39        1        1      98     39381
# 2         55712             58        0        1      19     34457
# 3         32316             47        0        0       6     27939
# 4         70429             19        1        1      90     38045
#
#    cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0              3              8  2005           0                  1
# 1              8              6  2015           1                  0
# 2              6              8  2021           0                  0
# 3             10              4  2012           0                  1
# 4              3              7  1990           1                  0
#
#    basement  attic  garage  hasStorageRoom  hasGuestRoom      price
# 0      4313   9005     956               0             7  7559081.5
# ...

# %%
dataset.corr()
# Out:
#                    squareMeters  numberOfRooms   hasYard   hasPool    floors  \
# squareMeters           1.000000       0.009573 -0.006650 -0.005594  0.001109
# numberOfRooms          0.009573       1.000000 -0.011240  0.017015  0.022244
# hasYard               -0.006650      -0.011240  1.000000  0.015514 -0.000883
# hasPool               -0.005594       0.017015  0.015514  1.000000 -0.004006
# floors                 0.001109       0.022244 -0.000883 -0.004006  1.000000
# cityCode              -0.001541       0.009040  0.006760  0.008072  0.002207
# cityPartRange          0.008758       0.008340  0.005023  0.014613 -0.004921
# numPrevOwners          0.016619       0.016766  0.004279 -0.006848  0.002463
# made                  -0.007207       0.003978  0.002214  0.001894  0.005022
# isNewBuilt            -0.010667      -0.002865 -0.008370  0.000188  0.002458
# hasStormProtector      0.007480      -0.001656 -0.007598 -0.001001 -0.008566
# ...

# %%
dataset.columns
# Out:
# Index(['squareMeters', 'numberOfRooms', 'hasYard', 'hasPool', 'floors',
#        'cityCode', 'cityPartRange', 'numPrevOwners', 'made', 'isNewBuilt',
#        'hasStormProtector', 'basement', 'attic', 'garage', 'hasStorageRoom',
#        'hasGuestRoom', 'price'],
#       dtype='object')

# %%
X = dataset[['squareMeters', 'numberOfRooms', 'hasYard', 'hasPool', 'floors',
       'cityCode', 'cityPartRange', 'numPrevOwners', 'made', 'isNewBuilt',
       'hasStormProtector', 'basement', 'attic', 'garage', 'hasStorageRoom',
       'hasGuestRoom']]

# %%
y = dataset['price']

# %%
# train an d test

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split (X, y, test_size=0.20, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
pricingmodel = LinearRegression()

# %%
model = pricingmodel.fit(X_train,y_train)

# %%
y_pred = model.predict(X_test)

# %%
y_pred     # we can call this yhat
# Out:
# array([7962638.49058964, 3715852.21234054, 8553849.80785994, ...,
#        1951271.36251268, 2945553.06899966, 7042691.64493203])

# %%
y_test    # we can call this y
# Out:
# 6252    7964369.6
# 4684    3713548.9
# 1731    8553019.2
# 4742    6428666.2
# 4521    6465184.9
#           ...
# 6412    6951279.2
# 8285    8152737.7
# 7853    1947709.8
# 1095    2944295.3
# 6929    7041725.7
# Name: price, Length: 2000, dtype: float64

# %%
pricingmodel.coef_
# Out:
# array([ 1.00000082e+02,  2.73938985e-01,  2.99385926e+03,  2.99310688e+03,
#         5.44652871e+01, -9.60349217e-04,  5.04585546e+01,  2.82108149e+00,
#        -3.18745921e+00,  1.28071127e+02,  1.02271312e+02, -8.18790012e-03,
#        -7.58194511e-03,  1.01284555e-01,  4.16234894e+01, -6.32791628e+00])
